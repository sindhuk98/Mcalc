# %% [markdown]
# <a href="https://colab.research.google.com/github/sindhuk98/Mcalc/blob/master/Drive_to_GCP_Bucket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from google.colab import auth
auth.authenticate_user()
project_id = 'mezzanine-244018'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
#
#
# To take a quick anonymous survey, run:
#   $ gcloud survey
#
# gs://artifacts.mezzanine-244018.appspot.com/
# gs://base64/
# gs://customer-data02/
# gs://cyber-security-data/
# gs://mezzanine-244018.appspot.com/
# gs://mezzanine-frontier/
# gs://real-estate-training/
# gs://real_estate_tagger/
# gs://staging.mezzanine-244018.appspot.com/
# gs://tagging-temp/

# %%
cat lsrila.txt | gsutil ls gs://real-estate-training/content-rila-nov6/posts/
# Out:
# Streaming output truncated to the last 5000 lines.
# gs://real-estate-training/content-rila-nov6/posts/e5a1ecc7-95a4-4cf2-bda4-40abbfc7a0a3.jpg
# gs://real-estate-training/content-rila-nov6/posts/e5a1ecc7-95a4-4cf2-bda4-40abbfc7a0a3_thumb.jpg
# gs://real-estate-training/content-rila-nov6/posts/e5a529cd-493e-4d9f-a8f4-3fbd5d80c962.jpg
# gs://real-estate-training/content-rila-nov6/posts/e5a529cd-493e-4d9f-a8f4-3fbd5d80c962_thumb.jpg
# gs://real-estate-training/content-rila-nov6/posts/e5ad4c56-6231-4547-a71d-9fd93512c7ed.jpg
# gs://real-estate-training/content-rila-nov6/posts/e5ad4c56-6231-4547-a71d-9fd93512c7ed_thumb.jpg
# gs://real-estate-training/content-rila-nov6/posts/e5ada4ab-22b8-4fdc-958d-4212814e9fb3.jpg
# gs://real-estate-training/content-rila-nov6/posts/e5ada4ab-22b8-4fdc-958d-4212814e9fb3_thumb.jpg
# gs://real-estate-training/content-rila-nov6/posts/e5b0d514-e82c-471b-9f2e-9eae760d1f31.jpg
# ...

# %% [markdown]
# # Copy files from Drive to GCP

# %%
bucket_name = 'House_test'

# !gsutil -m cp -r "/content/drive/My Drive/Image_dataset/validation data/flooring val/*" gs://real-estate-training/RAW_Objects/floor/
# Out:
# Copying file:///content/drive/My Drive/Image_dataset/validation data/flooring val/modern-vinyl-plank-flooring-vancouver-bc.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Image_dataset/validation data/flooring val/Products12155-233x309--524321200.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Image_dataset/validation data/flooring val/PASSION_LUX_90_2-WEBSITE.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Image_dataset/validation data/flooring val/provision-thumb-700x392.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Image_dataset/validation data/flooring val/santa_cruz_room_scene_5bae714dbd380_1000.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Image_dataset/validation data/flooring val/Pantheon-V2001-7049-Santa-Maria.jpg [Content-Type=image/jpeg]...
# ...

# %% [markdown]
# # Move/Rename Folder

# %%
# !gsutil mv gs://real-estate-training/RAW_HouseTest/House_test/manufactured_home/ gs://real-estate-training/RAW_HouseType/House_test
# Out:
# Copying gs://real-estate-training/RAW_HouseTest/House_test/manufactured_home/00000001.jpg [Content-Type=image/jpeg]...
# Removing gs://real-estate-training/RAW_HouseTest/House_test/manufactured_home/00000001.jpg...
# Copying gs://real-estate-training/RAW_HouseTest/House_test/manufactured_home/00004538.jpg [Content-Type=image/jpeg]...
# Removing gs://real-estate-training/RAW_HouseTest/House_test/manufactured_home/00004538.jpg...
# Copying gs://real-estate-training/RAW_HouseTest/House_test/manufactured_home/00004541.jpg [Content-Type=image/jpeg]...
# Removing gs://real-estate-training/RAW_HouseTest/House_test/manufactured_home/00004541.jpg...
# Copying gs://real-estate-training/RAW_HouseTest/House_test/manufactured_home/00004542.jpg [Content-Type=image/jpeg]...
# Removing gs://real-estate-training/RAW_HouseTest/House_test/manufactured_home/00004542.jpg...
#
# ==> NOTE: You are performing a sequence of gsutil operations that may
# ...

# %% [markdown]
# # Count of files

# %%
# !gsutil du  gs://real-estate-training/ADE20K_Dataset/training/b/** | wc -l
# Out:
# 13398

# %%
# !gsutil ls -l gs://real-estate-training/ADE20K_Dataset/training/*
# Out:
# Streaming output truncated to the last 5000 lines.
#       1549  2020-12-07T17:47:48Z  gs://real-estate-training/ADE20K_Dataset/training/misc/ADE_train_00012502_atr.txt
#       6290  2020-12-07T17:47:47Z  gs://real-estate-training/ADE20K_Dataset/training/misc/ADE_train_00012502_parts_1.png
#       1365  2020-12-07T17:47:47Z  gs://real-estate-training/ADE20K_Dataset/training/misc/ADE_train_00012502_parts_2.png
#       8863  2020-12-07T17:47:50Z  gs://real-estate-training/ADE20K_Dataset/training/misc/ADE_train_00012502_seg.png
#     343495  2020-12-07T17:47:48Z  gs://real-estate-training/ADE20K_Dataset/training/misc/ADE_train_00012503.jpg
#        427  2020-12-07T17:47:49Z  gs://real-estate-training/ADE20K_Dataset/training/misc/ADE_train_00012503_atr.txt
#      27751  2020-12-07T17:47:49Z  gs://real-estate-training/ADE20K_Dataset/training/misc/ADE_train_00012503_seg.png
#     554922  2020-12-07T17:47:50Z  gs://real-estate-training/ADE20K_Dataset/training/misc/ADE_train_00012504.jpg
# ...

# %%
# !gsutil ls gs://real-estate-training/ADE20K_Dataset/training/a/
# Out:
# gs://real-estate-training/ADE20K_Dataset/training/a/
# gs://real-estate-training/ADE20K_Dataset/training/a/abbey/
# gs://real-estate-training/ADE20K_Dataset/training/a/access_road/
# gs://real-estate-training/ADE20K_Dataset/training/a/air_base/
# gs://real-estate-training/ADE20K_Dataset/training/a/airfield/
# gs://real-estate-training/ADE20K_Dataset/training/a/airlock/
# gs://real-estate-training/ADE20K_Dataset/training/a/airplane_cabin/
# gs://real-estate-training/ADE20K_Dataset/training/a/airport/
# gs://real-estate-training/ADE20K_Dataset/training/a/airport_terminal/
# gs://real-estate-training/ADE20K_Dataset/training/a/airport_ticket_counter/
# gs://real-estate-training/ADE20K_Dataset/training/a/alcove/
# gs://real-estate-training/ADE20K_Dataset/training/a/alley/
# gs://real-estate-training/ADE20K_Dataset/training/a/amphitheater/
# gs://real-estate-training/ADE20K_Dataset/training/a/amusement_arcade/
# gs://real-estate-training/ADE20K_Dataset/training/a/amusement_park/
# ...

# %% [markdown]
# # Size of Folder

# %%
# !gsutil du -sh gs://real-estate-training/
# Out:
# 29.09 GiB    gs://real-estate-training
